# %%
import matplotlib.pyplot as plt
import json
from pathlib import Path

# %%
results_path = Path("../results/classification")

# %%
with open(results_path / "timm_models/timm_effnet_b0_lego_sorterV0_results.json", "r") as f:
    timm_results = json.load(f)

with open(results_path / "batch_1/efficientnet_b0_lego_sorter_test_results.json", "r") as f:
    tv_results = json.load(f)

# %%
timm_results.keys()
# Out:
# dict_keys(['learning_rate', 'train_loss', 'train_acc', 'test_loss', 'test_acc'])

# %%
plt.plot(timm_results["train_acc"])
plt.plot(timm_results["test_acc"])
plt.show()

plt.plot(tv_results["train_acc"])
plt.plot(tv_results["test_acc"])
plt.show()
